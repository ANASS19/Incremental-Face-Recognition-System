# %%
import os
import cv2
import numpy as np
import torch
from mtcnn import MTCNN
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm  # Progress bar

# Initialize MTCNN for face detection
detector = MTCNN()

# Dataset paths
LFW_PATH = "lfw-deepfunneled/lfw-deepfunneled"  # Path to LFW dataset
STUDENT_PATH = "student_images"  # Path to Student dataset
PROCESSED_PATH = "processed_faces"  # Directory to save processed images

# Ensure processed directory exists
os.makedirs(PROCESSED_PATH, exist_ok=True)

# Define Data Augmentation Transforms
augmentation_transforms = transforms.Compose([
    transforms.RandomRotation(degrees=10),  # Random Rotation
    transforms.RandomHorizontalFlip(),  # Horizontal Flip
    transforms.ColorJitter(brightness=0.2),  # Brightness Adjustment
    transforms.GaussianBlur(kernel_size=(5, 5)),  # Gaussian Noise
    transforms.ToTensor()
])

# Function to detect and align face
def detect_and_align_face(img_path):
    """Detects and extracts a face from an image using MTCNN."""
    if not os.path.exists(img_path):  # Check if file exists
        print(f"Error: File {img_path} not found.")
        return None
    
    img = cv2.imread(img_path)
    if img is None:  # If OpenCV fails to read the image
        print(f"Error: Unable to read image {img_path}")
        return None

    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    faces = detector.detect_faces(img_rgb)

    if len(faces) > 0:
        x, y, w, h = faces[0]['box']
        face = img_rgb[y:y+h, x:x+w]  # Crop detected face
        face_resized = cv2.resize(face, (160, 160))  # Resize for FaceNet
        return face_resized
    return None

# Process both LFW & Student datasets
for dataset_path in [LFW_PATH, STUDENT_PATH]:
    print(f"\nProcessing dataset: {dataset_path}...")
    
    for person in tqdm(os.listdir(dataset_path)):  # Show progress bar
        person_path = os.path.join(dataset_path, person)
        
        if not os.path.isdir(person_path):  # Ensure it's a directory
            continue

        # Create a directory for processed faces
        processed_person_path = os.path.join(PROCESSED_PATH, person)
        os.makedirs(processed_person_path, exist_ok=True)

        for img_name in os.listdir(person_path):
            img_path = os.path.join(person_path, img_name)

            # Ensure only valid image files are processed
            valid_extensions = (".jpg", ".jpeg", ".png")
            if not img_name.lower().endswith(valid_extensions):
                continue

            processed_img = detect_and_align_face(img_path)

            if processed_img is not None:
                # Convert to PIL image for augmentation
                img_pil = Image.fromarray(processed_img)

                # Save original image
                img_pil.save(os.path.join(processed_person_path, img_name))

                # Apply augmentation and save augmented image
                augmented_img = augmentation_transforms(img_pil)
                augmented_img = transforms.ToPILImage()(augmented_img)
                augmented_img.save(os.path.join(processed_person_path, f"aug_{img_name}"))

print("\n✅ Preprocessing & Data Augmentation Completed Successfully!")

# Show Before & After Augmentation
def show_augmentation(img_path):
    """Displays an image before and after data augmentation."""
    img = Image.open(img_path)
    augmented_img = augmentation_transforms(img)
    
    fig, ax = plt.subplots(1, 2, figsize=(8, 4))
    ax[0].imshow(img)
    ax[0].set_title("Original Image")
    ax[0].axis("off")
    
    ax[1].imshow(transforms.ToPILImage()(augmented_img))
    ax[1].set_title("Augmented Image")
    ax[1].axis("off")
    
    plt.show()

# Example: Display an image before & after augmentation
example_person = os.listdir(PROCESSED_PATH)[0]  # Pick a random person
example_image_path = os.path.join(PROCESSED_PATH, example_person, os.listdir(os.path.join(PROCESSED_PATH, example_person))[0])

print(f"\nDisplaying example image before & after augmentation: {example_image_path}")
show_augmentation(example_image_path)
# Out:
# Processing dataset: lfw-deepfunneled/lfw-deepfunneled...
# 100%|██████████| 5749/5749 [30:05<00:00,  3.18it/s]
# Processing dataset: student_images...
# 100%|██████████| 7/7 [00:08<00:00,  1.25s/it]
# ✅ Preprocessing & Data Augmentation Completed Successfully!
#
# Displaying example image before & after augmentation: processed_faces\Aaron_Eckhart\Aaron_Eckhart_0001.jpg

# %%
import os
import torch
import numpy as np
import torchvision.transforms as transforms
from PIL import Image
from tqdm import tqdm
from facenet_pytorch import InceptionResnetV1  # Pretrained FaceNet model

# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load the pretrained FaceNet model
facenet_model = InceptionResnetV1(pretrained='vggface2').eval().to(device)

# Define the preprocessing pipeline
transform = transforms.Compose([
    transforms.Resize((160, 160)),  # Ensure image is 160x160
    transforms.ToTensor(),  # Convert to tensor
    transforms.Normalize([0.5], [0.5])  # Normalize to range [-1, 1]
])

# Paths
PROCESSED_PATH = "processed_faces"  # Directory with preprocessed images
EMBEDDINGS_PATH = "face_embeddings.npz"  # File to save embeddings

# Dictionary to store embeddings and labels
embeddings = []
labels = []

# Extract embeddings for all images
print("\nExtracting face embeddings...")
for person in tqdm(os.listdir(PROCESSED_PATH)):  # Iterate over each person
    person_path = os.path.join(PROCESSED_PATH, person)
    
    if not os.path.isdir(person_path):
        continue  # Skip non-directory files

    for img_name in os.listdir(person_path):
        img_path = os.path.join(person_path, img_name)

        # Open image and apply transformations
        img = Image.open(img_path).convert('RGB')
        img_tensor = transform(img).unsqueeze(0).to(device)  # Add batch dimension

        # Extract 512-d embedding
        with torch.no_grad():
            embedding = facenet_model(img_tensor).cpu().numpy().flatten()
        
        embeddings.append(embedding)
        labels.append(person)

# Convert lists to NumPy arrays
embeddings = np.array(embeddings)
labels = np.array(labels)

# Save embeddings for future use
np.savez_compressed(EMBEDDINGS_PATH, embeddings=embeddings, labels=labels)
print(f"\n✅ Face embeddings extracted and saved to {EMBEDDINGS_PATH}!")

# Display an example embedding
print(f"\nExample Embedding (First Image):\n{embeddings[0]}")
print(f"Associated Label: {labels[0]}")
# Out:
# Using device: cuda
#
# Extracting face embeddings...
# 100%|██████████| 5756/5756 [10:00<00:00,  9.59it/s]
# ✅ Face embeddings extracted and saved to face_embeddings.npz!
#
# Example Embedding (First Image):
# [-0.01341883 -0.08670852 -0.05174877  0.01656888  0.01389744 -0.0454387
#  -0.01195512 -0.03502641  0.00423315  0.00520281  0.00764716  0.06291418
#   0.01870861 -0.02379206 -0.01237745  0.13394317 -0.03827729 -0.06521268
#   0.07242876 -0.01128361  0.05079532 -0.0308378  -0.00212347  0.06160292
#   0.0223365  -0.10094447  0.01147893 -0.00757547 -0.09908097  0.02330132
#   0.01180472 -0.09720135 -0.04556138  0.01323234 -0.05350938  0.01232778
#   0.03452069  0.06162421 -0.05300042 -0.03990328 -0.02033284  0.054569
#   0.0317312   0.01729401 -0.00304814  0.10589206  0.04204415 -0.04708214
#   0.01964215  0.08608436  0.05060911  0.01230394 -0.00818227 -0.08886955
#  -0.03670169 -0.01156924  0.09645295 -0.07334445 -0.01082147  0.06220363
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import TensorDataset, DataLoader

# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load face embeddings and labels
data = np.load("face_embeddings.npz")
embeddings = data["embeddings"]
labels = data["labels"]

# Encode labels as integers
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

# Split data into training & testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(embeddings, labels_encoded, test_size=0.2, random_state=42)

# Convert NumPy arrays to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.long).to(device)
y_test_tensor = torch.tensor(y_test, dtype=torch.long).to(device)

# Create DataLoader for batching
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Define the Classifier Model
class FaceClassifier(nn.Module):
    def __init__(self, input_size, num_classes):
        super(FaceClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, 256)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(256, 128)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(128, num_classes)
    
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        return x

# Initialize Model
num_classes = len(np.unique(labels_encoded))
model = FaceClassifier(input_size=512, num_classes=num_classes).to(device)

# Loss function & Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training Parameters
num_epochs = 20
train_losses = []
test_accuracies = []

# Training Loop
print("\n🔹 Training the Classifier...")
for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    # Store training loss
    avg_loss = total_loss / len(train_loader)
    train_losses.append(avg_loss)

    # Evaluate Model on Test Data
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            outputs = model(X_batch)
            _, predicted = torch.max(outputs, 1)
            total += y_batch.size(0)
            correct += (predicted == y_batch).sum().item()

    accuracy = correct / total
    test_accuracies.append(accuracy)

    print(f"Epoch [{epoch+1}/{num_epochs}] - Loss: {avg_loss:.4f}, Test Accuracy: {accuracy:.4f}")

print("\n✅ Training Completed!")

# Plot Accuracy & Loss Graphs
plt.figure(figsize=(12, 5))

# Loss Curve
plt.subplot(1, 2, 1)
plt.plot(range(num_epochs), train_losses, label="Training Loss", color="red")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss Curve")
plt.legend()

# Accuracy Curve
plt.subplot(1, 2, 2)
plt.plot(range(num_epochs), test_accuracies, label="Test Accuracy", color="blue")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Test Accuracy Curve")
plt.legend()

plt.show()

# Save Model
torch.save(model.state_dict(), "face_classifier.pth")
print("\n✅ Model saved as 'face_classifier.pth'")
# Out:
# Using device: cuda
#
# 🔹 Training the Classifier...
# Epoch [1/20] - Loss: 7.3219, Test Accuracy: 0.1705
# Epoch [2/20] - Loss: 5.2385, Test Accuracy: 0.3450
# Epoch [3/20] - Loss: 2.8874, Test Accuracy: 0.5151
# Epoch [4/20] - Loss: 1.1339, Test Accuracy: 0.6010
# Epoch [5/20] - Loss: 0.5012, Test Accuracy: 0.7237
# Epoch [6/20] - Loss: 0.2542, Test Accuracy: 0.7856
# Epoch [7/20] - Loss: 0.1478, Test Accuracy: 0.8059
# Epoch [8/20] - Loss: 0.0917, Test Accuracy: 0.8113
# Epoch [9/20] - Loss: 0.0573, Test Accuracy: 0.8237
# Epoch [10/20] - Loss: 0.0399, Test Accuracy: 0.8243
# Epoch [11/20] - Loss: 0.0275, Test Accuracy: 0.8288
# Epoch [12/20] - Loss: 0.0221, Test Accuracy: 0.8382
# Epoch [13/20] - Loss: 0.0224, Test Accuracy: 0.8331
# Epoch [14/20] - Loss: 0.0171, Test Accuracy: 0.8380
# Epoch [15/20] - Loss: 0.0205, Test Accuracy: 0.8397
# Epoch [16/20] - Loss: 0.0193, Test Accuracy: 0.8393
# Epoch [17/20] - Loss: 0.0112, Test Accuracy: 0.8553
# ...

# %%
import torch
import torch.nn as nn
import numpy as np
import cv2
from PIL import Image
import torchvision.transforms as transforms
from facenet_pytorch import InceptionResnetV1
from sklearn.preprocessing import LabelEncoder
import os

# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load Pretrained FaceNet Model (For Embeddings)
facenet_model = InceptionResnetV1(pretrained='vggface2').eval().to(device)

# Load the trained classifier model
class FaceClassifier(nn.Module):
    def __init__(self, input_size, num_classes):
        super(FaceClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, 256)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(256, 128)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(128, num_classes)
    
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        return x

# Load existing embeddings & labels
data = np.load("face_embeddings.npz")
embeddings = list(data["embeddings"])  # Convert to list for easy updates
labels = list(data["labels"])

# Encode labels
label_encoder = LabelEncoder()
label_encoder.fit(labels)

# Load trained classifier
num_classes = len(np.unique(labels))
classifier = FaceClassifier(input_size=512, num_classes=num_classes).to(device)
classifier.load_state_dict(torch.load("face_classifier.pth"))
classifier.eval()

# Face Detection & Preprocessing Function
def preprocess_face(image_path):
    transform = transforms.Compose([
        transforms.Resize((160, 160)),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ])
    img = Image.open(image_path).convert("RGB")
    img_tensor = transform(img).unsqueeze(0).to(device)
    return img_tensor

# Function to Extract Face Embedding
def extract_embedding(image_path):
    img_tensor = preprocess_face(image_path)
    with torch.no_grad():
        embedding = facenet_model(img_tensor).cpu().numpy().flatten()
    return embedding

# Function to Recognize a Face
def recognize_face(image_path):
    new_embedding = extract_embedding(image_path)

    # Compute similarity with stored embeddings
    similarities = [np.linalg.norm(new_embedding - emb) for emb in embeddings]

    min_distance = min(similarities)
    min_index = similarities.index(min_distance)
    threshold = 0.8  # Adjust based on performance

    if min_distance < threshold:
        recognized_person = labels[min_index]
        print(f"✅ Recognized as: {recognized_person}")
        return recognized_person
    else:
        print("❌ Face not recognized! New student detected.")
        return None

# Function to Enroll a New Student
""" enroll_new_student(image_path, student_name):
    global classifier

    # Extract embedding
    new_embedding = extract_embedding(image_path)
    embeddings.append(new_embedding)
    labels.append(student_name)

    # Update label encoder
    label_encoder.fit(labels)
    num_classes = len(label_encoder.classes_)

    # Create new classifier with updated number of classes
    updated_classifier = FaceClassifier(input_size=512, num_classes=num_classes).to(device)
    updated_classifier.load_state_dict(classifier.state_dict())  # Copy existing weights

    # Add new student class by fine-tuning the last layer
    new_fc3 = nn.Linear(128, num_classes).to(device)
    new_fc3.weight.data[:-1] = classifier.fc3.weight.data  # Retain old weights
    updated_classifier.fc3 = new_fc3

    # Save updated model & embeddings
    classifier = updated_classifier
    torch.save(classifier.state_dict(), "face_classifier.pth")
    np.savez_compressed("face_embeddings.npz", embeddings=np.array(embeddings), labels=np.array(labels))
    
    print(f"✅ New student '{student_name}' enrolled successfully!")

"""
def enroll_new_student(image_path, student_name):
    global classifier, embeddings, labels, label_encoder  # Ensure updates persist

    # Extract embedding for the new student
    new_embedding = extract_embedding(image_path)
    embeddings.append(new_embedding)
    labels.append(student_name)

    # Update label encoder with new student
    label_encoder.fit(labels)
    num_classes = len(label_encoder.classes_)

    # Create new classifier with updated number of classes
    updated_classifier = FaceClassifier(input_size=512, num_classes=num_classes).to(device)

    # Load old weights except for the last layer
    old_state_dict = classifier.state_dict()
    new_state_dict = updated_classifier.state_dict()

    # Copy all layers except fc3
    for key in old_state_dict.keys():
        if "fc3" not in key:  # Ignore final layer
            new_state_dict[key] = old_state_dict[key]

    # Initialize only the new class weights for fc3
    new_state_dict["fc3.weight"][:-1] = old_state_dict["fc3.weight"]
    new_state_dict["fc3.bias"][:-1] = old_state_dict["fc3.bias"]

    # Assign updated weights to the new model
    updated_classifier.load_state_dict(new_state_dict)

    # Save the updated model and embeddings
    classifier = updated_classifier
    torch.save(classifier.state_dict(), "face_classifier.pth")
    np.savez_compressed("face_embeddings.npz", embeddings=np.array(embeddings), labels=np.array(labels))

    print(f"✅ New student '{student_name}' enrolled successfully!")


# Example Usage
image_path = "new_student.jpg"  # Replace with actual student image path
recognized_name = recognize_face(image_path)

if recognized_name is None:
    student_name = input("Enter new student name: ")
    enroll_new_student(image_path, student_name)
# Out:
# Using device: cuda
# ❌ Face not recognized! New student detected.
# ✅ New student 'mohamed oubia' enrolled successfully!

# %%
import cv2
import torch
import numpy as np
from facenet_pytorch import InceptionResnetV1, MTCNN
import torchvision.transforms as transforms
from PIL import Image
import torch.nn as nn
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load Pretrained FaceNet Model (on GPU)
facenet_model = InceptionResnetV1(pretrained='vggface2').eval().to(device)

# Load Face Detector (MTCNN) on CPU
mtcnn = MTCNN(keep_all=True, device="cpu")  # Force CPU usage for MTCNN

# Load Stored Embeddings & Labels
data = np.load("face_embeddings.npz")
embeddings = list(data["embeddings"])  
labels = list(data["labels"])

# Encode Labels
label_encoder = LabelEncoder()
label_encoder.fit(labels)

# Load Trained Classifier
class FaceClassifier(nn.Module):
    def __init__(self, input_size, num_classes):
        super(FaceClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, 256)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(256, 128)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(128, num_classes)
    
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        return x

num_classes = len(np.unique(labels))
classifier = FaceClassifier(input_size=512, num_classes=num_classes).to(device)
classifier.load_state_dict(torch.load("face_classifier.pth"))
classifier.eval()

# Preprocessing Function
def preprocess_face(img):
    transform = transforms.Compose([
        transforms.Resize((160, 160)),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ])
    img = Image.fromarray(img).convert("RGB")
    img_tensor = transform(img).unsqueeze(0).to(device)
    return img_tensor

# Function to Extract Face Embedding
def extract_embedding(face_img):
    img_tensor = preprocess_face(face_img)
    with torch.no_grad():
        embedding = facenet_model(img_tensor).cpu().numpy().flatten()
    return embedding

# Function to Recognize a Face
def recognize_face(face_img):
    new_embedding = extract_embedding(face_img)

    # Compute similarity with stored embeddings
    similarities = [np.linalg.norm(new_embedding - emb) for emb in embeddings]
    min_distance = min(similarities)
    min_index = similarities.index(min_distance)
    threshold = 0.8  # Adjust based on testing

    if min_distance < threshold:
        recognized_person = labels[min_index]
        return recognized_person, True  # Match Found
    else:
        return None, False  # No Match

# Start Real-Time Recognition (Webcam)
cap = cv2.VideoCapture(0)

print("\n🔹 Starting Real-Time Face Recognition...")

while True:
    ret, frame = cap.read()
    if not ret:
        continue

    # Convert frame to RGB and PIL format
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  
    frame_pil = Image.fromarray(frame_rgb)

    # Detect Faces (Force MTCNN on CPU)
    boxes, _ = mtcnn.detect(frame_pil)

    if boxes is not None:
        for box in boxes:
            x, y, w, h = map(int, box)
            face = frame[y:h, x:w]

            # Recognize Face
            recognized_name, is_authorized = recognize_face(face)

            # Draw Bounding Box & Display Name
            color = (0, 255, 0) if is_authorized else (0, 0, 255)  # Green for authorized, Red for not authorized
            text = recognized_name if is_authorized else "Not Authorized"
            cv2.rectangle(frame, (x, y), (w, h), color, 2)
            cv2.putText(frame, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

    # Show Webcam Output
    #cv2.imhow("Face Recognition", frame)
    plt.figure(figsize=(8, 6))
    plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct color display
    plt.axis("off")
    plt.show()

    # Press 'q' to Quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
print("\n🛑 Stopping Real-Time Face Recognition...")
# Out:
# Using device: cuda
#
# 🔹 Starting Real-Time Face Recognition...
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 125
#     122     plt.show()
#     124     # Press 'q' to Quit
# --> 125     if cv2.waitKey(1) & 0xFF == ord('q'):
#     126         break
#     127 cap.release()
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1367: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvWaitKey'

# %%
import cv2
import torch
import numpy as np
import matplotlib.pyplot as plt
from facenet_pytorch import InceptionResnetV1, MTCNN
import torchvision.transforms as transforms
from PIL import Image
import torch.nn as nn
from sklearn.preprocessing import LabelEncoder

# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load Pretrained FaceNet Model
facenet_model = InceptionResnetV1(pretrained='vggface2').eval().to(device)

# Load Face Detector (MTCNN) on CPU to avoid NMS CUDA issues
mtcnn = MTCNN(keep_all=True, device="cpu")

# Load Stored Embeddings & Labels
data = np.load("face_embeddings.npz")
embeddings = list(data["embeddings"])  
labels = list(data["labels"])

# Encode Labels
label_encoder = LabelEncoder()
label_encoder.fit(labels)

# Load Trained Classifier
class FaceClassifier(nn.Module):
    def __init__(self, input_size, num_classes):
        super(FaceClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, 256)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(256, 128)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(128, num_classes)
    
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        return x

num_classes = len(np.unique(labels))
classifier = FaceClassifier(input_size=512, num_classes=num_classes).to(device)
classifier.load_state_dict(torch.load("face_classifier.pth"))
classifier.eval()

# Preprocessing Function
def preprocess_face(img):
    transform = transforms.Compose([
        transforms.Resize((160, 160)),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ])
    img = Image.fromarray(img).convert("RGB")
    img_tensor = transform(img).unsqueeze(0).to(device)
    return img_tensor

# Function to Extract Face Embedding
def extract_embedding(face_img):
    img_tensor = preprocess_face(face_img)
    with torch.no_grad():
        embedding = facenet_model(img_tensor).cpu().numpy().flatten()
    return embedding

# Function to Recognize a Face
def recognize_face(face_img):
    new_embedding = extract_embedding(face_img)

    # Compute similarity with stored embeddings
    similarities = [np.linalg.norm(new_embedding - emb) for emb in embeddings]
    min_distance = min(similarities)
    min_index = similarities.index(min_distance)
    threshold = 0.8  # Adjust based on testing

    if min_distance < threshold:
        recognized_person = labels[min_index]
        return recognized_person, True  # Match Found
    else:
        return None, False  # No Match

# Start Real-Time Recognition (Webcam)
cap = cv2.VideoCapture(0)

print("\n🔹 Starting Real-Time Face Recognition...")

while True:
    ret, frame = cap.read()
    if not ret:
        break  # Exit loop if no frame is captured

    # Convert frame to RGB and PIL format
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  
    frame_pil = Image.fromarray(frame_rgb)

    # Detect Faces (MTCNN on CPU)
    boxes, _ = mtcnn.detect(frame_pil)

    if boxes is not None:
        for box in boxes:
            x, y, w, h = map(int, box)
            face = frame[y:h, x:w]

            # Recognize Face
            recognized_name, is_authorized = recognize_face(face)

            # Draw Bounding Box & Display Name
            color = (0, 255, 0) if is_authorized else (255, 0, 0)  # Green for authorized, Red for not authorized
            text = recognized_name if is_authorized else "Not Authorized"

            # Draw box on the frame
            frame = cv2.rectangle(frame, (x, y), (w, h), color, 2)
            frame = cv2.putText(frame, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

    # Display the frame using Matplotlib instead of cv2.imshow()
    plt.figure(figsize=(8, 6))
    plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct color display
    plt.axis("off")
    plt.show(block=False)  # Prevents blocking, allowing continuous display
    plt.pause(0.1)  # Short pause to allow updating the frame
    plt.clf()  # Clear the figure for the next frame

    # Instead of cv2.waitKey(), use input() to break the loop manually
    user_input = input("Press Enter to continue, or type 'q' to quit: ")
    if user_input.lower() == 'q':
        break

cap.release()
# Out:
# Using device: cuda
#
# 🔹 Starting Real-Time Face Recognition...

# %%
import cv2
import torch
import numpy as np
import matplotlib.pyplot as plt
from facenet_pytorch import InceptionResnetV1, MTCNN
import torchvision.transforms as transforms
from PIL import Image
import torch.nn as nn
from sklearn.preprocessing import LabelEncoder

# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load Pretrained FaceNet Model
facenet_model = InceptionResnetV1(pretrained='vggface2').eval().to(device)

# Load Face Detector (MTCNN) on CPU to avoid NMS CUDA issues
mtcnn = MTCNN(keep_all=True, device="cpu")

# Load Stored Embeddings & Labels
data = np.load("face_embeddings.npz")
embeddings = list(data["embeddings"])  
labels = list(data["labels"])

# Encode Labels
label_encoder = LabelEncoder()
label_encoder.fit(labels)

# Load Trained Classifier
class FaceClassifier(nn.Module):
    def __init__(self, input_size, num_classes):
        super(FaceClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, 256)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(256, 128)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(128, num_classes)
    
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        return x

num_classes = len(np.unique(labels))
classifier = FaceClassifier(input_size=512, num_classes=num_classes).to(device)
classifier.load_state_dict(torch.load("face_classifier.pth"))
classifier.eval()

# Preprocessing Function
def preprocess_face(img):
    transform = transforms.Compose([
        transforms.Resize((160, 160)),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ])
    img = Image.fromarray(img).convert("RGB")
    img_tensor = transform(img).unsqueeze(0).to(device)
    return img_tensor

# Function to Extract Face Embedding
def extract_embedding(face_img):
    img_tensor = preprocess_face(face_img)
    with torch.no_grad():
        embedding = facenet_model(img_tensor).cpu().numpy().flatten()
    return embedding

# Function to Recognize a Face
def recognize_face(face_img):
    new_embedding = extract_embedding(face_img)

    # Compute similarity with stored embeddings
    similarities = [np.linalg.norm(new_embedding - emb) for emb in embeddings]
    min_distance = min(similarities)
    min_index = similarities.index(min_distance)
    threshold = 0.8  # Adjust based on testing

    if min_distance < threshold:
        recognized_person = labels[min_index]
        return recognized_person, True  # Match Found
    else:
        return None, False  # No Match

# Start Real-Time Recognition (Webcam)
cap = cv2.VideoCapture(0)

plt.ion()  # Turn on interactive mode for continuous updates

print("\n🔹 Starting Real-Time Face Recognition...")

while True:
    ret, frame = cap.read()
    if not ret:
        continue

    # Convert frame to RGB and PIL format
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  
    frame_pil = Image.fromarray(frame_rgb)

    # Detect Faces (MTCNN on CPU)
    boxes, _ = mtcnn.detect(frame_pil)

    if boxes is not None:
        for box in boxes:
            x, y, w, h = map(int, box)
            face = frame[y:h, x:w]

            # Recognize Face
            recognized_name, is_authorized = recognize_face(face)

            # Draw Bounding Box & Display Name
            color = (0, 255, 0) if is_authorized else (255, 0, 0)  # Green for authorized, Red for not authorized
            text = recognized_name if is_authorized else "Not Authorized"

            # Draw box and label on the frame
            cv2.rectangle(frame, (x, y), (w, h), color, 2)
            cv2.putText(frame, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

    # Display the frame using Matplotlib (Real-Time Update)
    plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct color display
    plt.axis("off")
    plt.draw()  # Update the figure
    plt.pause(0.01)  # Pause to allow continuous updates
    plt.clf()  # Clear the figure for the next frame

    # Press 'q' to Quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
plt.ioff()  # Turn off interactive mode
plt.close()
print("\n🛑 Stopping Real-Time Face Recognition...")
# Out:
# Using device: cuda
#
# 🔹 Starting Real-Time Face Recognition...
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 130
#     127     plt.clf()  # Clear the figure for the next frame
#     129     # Press 'q' to Quit
# --> 130     if cv2.waitKey(1) & 0xFF == ord('q'):
#     131         break
#     133 cap.release()
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1367: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvWaitKey'

# %%
import cv2
import torch
import numpy as np
from facenet_pytorch import InceptionResnetV1, MTCNN
import torchvision.transforms as transforms
from PIL import Image
import torch.nn as nn
from sklearn.preprocessing import LabelEncoder

# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load Pretrained FaceNet Model
facenet_model = InceptionResnetV1(pretrained='vggface2').eval().to(device)

# Load Face Detector (MTCNN)
mtcnn = MTCNN(keep_all=True, device="cpu")  # Keep MTCNN on CPU for stability

# Load Stored Embeddings & Labels
data = np.load("face_embeddings.npz")
embeddings = list(data["embeddings"])  
labels = list(data["labels"])

# Encode Labels
label_encoder = LabelEncoder()
label_encoder.fit(labels)

# Load Trained Classifier
class FaceClassifier(nn.Module):
    def __init__(self, input_size, num_classes):
        super(FaceClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, 256)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(256, 128)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(128, num_classes)
    
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        return x

num_classes = len(np.unique(labels))
classifier = FaceClassifier(input_size=512, num_classes=num_classes).to(device)
classifier.load_state_dict(torch.load("face_classifier.pth"))
classifier.eval()

# Preprocessing Function
def preprocess_face(img):
    transform = transforms.Compose([
        transforms.Resize((160, 160)),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ])
    img = Image.fromarray(img).convert("RGB")
    img_tensor = transform(img).unsqueeze(0).to(device)
    return img_tensor

# Function to Extract Face Embedding
def extract_embedding(face_img):
    img_tensor = preprocess_face(face_img)
    with torch.no_grad():
        embedding = facenet_model(img_tensor).cpu().numpy().flatten()
    return embedding

# Function to Recognize a Face
def recognize_face(frame):
    # Detect Faces
    boxes, _ = mtcnn.detect(frame)

    if boxes is not None:
        for box in boxes:
            x, y, w, h = map(int, box)
            face = frame[y:h, x:w]  # Crop face

            # Extract embedding and match with stored data
            new_embedding = extract_embedding(face)
            similarities = [np.linalg.norm(new_embedding - emb) for emb in embeddings]
            min_distance = min(similarities)
            min_index = similarities.index(min_distance)
            threshold = 0.8  # Adjust based on testing

            if min_distance < threshold:
                recognized_person = labels[min_index]
                return recognized_person
    return "Unknown"  # Return "Unknown" if no match found

# Function to Enroll a New Student
def enroll_new_student(name, frame):
    global embeddings, labels, label_encoder

    # Detect face and extract embedding
    boxes, _ = mtcnn.detect(frame)

    if boxes is not None:
        for box in boxes:
            x, y, w, h = map(int, box)
            face = frame[y:h, x:w]  # Crop face
            new_embedding = extract_embedding(face)

            embeddings.append(new_embedding)
            labels.append(name)
            label_encoder.fit(labels)

            # Save updated embeddings
            np.savez_compressed("face_embeddings.npz", embeddings=np.array(embeddings), labels=np.array(labels))
            print(f"✅ New student '{name}' enrolled successfully!")

# **Start Real-Time Face Recognition**
cap = cv2.VideoCapture(0)

print("\n🔹 Starting Real-Time Face Recognition... (Press 'q' to exit, 'n' to enroll new student)")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    predicted_name = recognize_face(frame)

    if predicted_name and predicted_name != "Unknown":
        text = f"✅ Access Granted: {predicted_name}"
        color = (0, 255, 0)  # Green for recognized faces
    else:
        text = "❌ Access Denied"
        color = (0, 0, 255)  # Red for unknown faces

    # Display result
    cv2.putText(frame, text, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)
    cv2.imshow("Real-Time Face Recognition", frame)

    # Press 'n' to enroll a new student
    if cv2.waitKey(1) & 0xFF == ord('n'):
        name = input("Enter new student's name: ")
        enroll_new_student(name, frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Using device: cuda
#
# 🔹 Starting Real-Time Face Recognition... (Press 'q' to exit, 'n' to enroll new student)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 134
#     132 # Display result
#     133 cv2.putText(frame, text, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)
# --> 134 cv2.imshow("Real-Time Face Recognition", frame)
#     136 # Press 'n' to enroll a new student
#     137 if cv2.waitKey(1) & 0xFF == ord('n'):
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'
